# %%
import lmdb
import cv2
import os
import glob

def check_image_is_valid(image_path):
    try:
        img = cv2.imread(image_path)
        if img is None:
            return False
        return True
    except Exception:
        return False

def write_cache(env, cache):
    with env.begin(write=True) as txn:
        for k, v in cache.items():
            txn.put(k.encode(), v)

def create_lmdb_dataset(image_dir, label_file, output_path):
    os.makedirs(output_path, exist_ok=True)
    env = lmdb.open(output_path, map_size=2 * 1024 * 1024 * 1024)  # 2GB

    cache = {}
    cnt = 0

    with open(label_file, "r", encoding="utf-8") as f:
        lines = f.readlines()

    for line in lines:
        img_path, label = line.strip().split("\t")

        img_path = os.path.join(image_dir, img_path)

        if not os.path.exists(img_path) or not check_image_is_valid(img_path):
            print(f"Skip invalid image: {img_path}")
            continue

        with open(img_path, "rb") as img_file:
            image_bin = img_file.read()

        cache[f'image-{cnt:09d}'] = image_bin
        cache[f'label-{cnt:09d}'] = label.encode('utf-8')

        cnt += 1

        if cnt % 1000 == 0:
            write_cache(env, cache)
            cache = {}
            print(f"{cnt} images processed.")

    # Write remaining cache
    if cache:
        write_cache(env, cache)
        print(f"Final {cnt} images processed.")

    print(f"Dataset created at: {output_path}")

if __name__ == "__main__":
    image_dir = "./dataset/train_images/"
    label_file = "./dataset/train_labels.txt"
    output_path = "./train_data/data_lmdb_release/training/"
    create_lmdb_dataset(image_dir, label_file, output_path)
# Out:
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(1).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(1000).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100000).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100001).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100002).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100003).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100004).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100005).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100006).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100007).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100008).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100009).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10001).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100010).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100011).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100012).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100013).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100014).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100015).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100016).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100017).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100018).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100019).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10002).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100020).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100021).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100021).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100022).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100023).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100024).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100025).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100026).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100027).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100028).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100029).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10003).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100030).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100031).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100032).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100033).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100033).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100034).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100035).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100036).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100037).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100038).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100039).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10004).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100041).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100042).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100043).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100044).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100045).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100046).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100047).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100048).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10005).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100050).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100051).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100052).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100053).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100054).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100055).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100056).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100057).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100058).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100059).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10006).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100060).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100061).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100062).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100063).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100064).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100065).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100066).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100067).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100068).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100069).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10007).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100070).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100071).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100072).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100073).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100074).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100075).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100076).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100077).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100078).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10008).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100081).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100082).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100083).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100084).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100085).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100086).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100087).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100088).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100089).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10009).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100090).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100091).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100092).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100093).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100094).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100095).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100096).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100097).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100098).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100099).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10010).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100100).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100101).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100102).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100103).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100104).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100105).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100106).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100106).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100106).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100107).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100108).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100109).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10011).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100110).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100111).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100111).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100112).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100113).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100114).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100115).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100116).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100117).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100118).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100119).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100120).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100121).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100122).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100123).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100124).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100125).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100126).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100127).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100128).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100129).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10013).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100131).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100132).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100133).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100134).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100135).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100136).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100137).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100138).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100139).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10014).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100140).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100141).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100142).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100143).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100144).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100145).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100146).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100147).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100148).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100149).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10015).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100150).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100151).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100152).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100153).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100154).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100155).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(
png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100470).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100471).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100472).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100473).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100474).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100475).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100476).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100477).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100478).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100479).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10048).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100481).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100482).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100483).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100484).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100485).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100486).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100487).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100488).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100489).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10049).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10049).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100490).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100491).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100492).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100493).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100494).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100495).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100496).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100497).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100498).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100499).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(1005).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10050).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100501).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100503).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100504).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100505).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100506).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(100507).png
# ...
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103154).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103166).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103168).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103172).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103177).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103193).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103199).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103205).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103206).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103222).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103229).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10323).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103237).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103238).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103244).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103248).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103267).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10327).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103279).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103281).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103286).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103290).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103297).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103298).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103299).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(1033).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103306).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103309).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103315).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103317).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10333).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103332).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103347).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103350).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103351).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103352).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103354).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103359).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103361).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103373).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103374).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10338).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103381).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103384).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103387).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10339).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103402).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103403).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103406).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103422).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103424).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103429).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103430).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103432).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103438).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103441).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103443).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103449).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103460).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103461).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103470).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103481).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103486).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103490).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103494).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103510).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103514).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10352).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103521).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103524).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103529).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103544).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103546).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103558).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10356).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103560).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103561).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103562).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103578).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103581).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103586).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103594).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103596).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103597).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103620).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103622).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103630).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103640).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103647).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103651).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10366).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103664).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103665).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103670).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103687).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103692).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103704).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103706).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103719).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103735).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103736).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103739).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103742).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103743).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103745).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10375).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103750).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103767).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103776).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103783).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103788).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103794).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103806).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103811).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103816).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103818).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103822).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10383).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103837).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103844).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103845).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103856).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103863).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103864).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10387).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103871).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103876).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103918).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103922).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103944).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103954).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103966).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103970).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103976).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103982).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103983).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103998).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(103999).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104008).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104009).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10401).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104015).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104018).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104038).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104049).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104055).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104056).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104057).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104065).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(10407).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104086).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104087).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104088).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104096).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(1041).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104102).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104105).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104106).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104113).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104118).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104123).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104126).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104140).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104141).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104142).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104144).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104149).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104167).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104178).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104192).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104193).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104195).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104197).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104206).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104212).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104216).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104221).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104233).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104237).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104248).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104254).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104255).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104259).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104269).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104275).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104281).png
# Skip invalid image: D:/Private/Project/kaggle/OCR/data_OCR/final_data\2a(104284).png
# Dataset created at: ./train_data/data_lmdb_release/training/

# %%
# Out:
# PaddlePaddle Version: 2.6.2
# CUDA Available: True
# GPU Count: 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 8
#       6 if paddle.device.is_compiled_with_cuda():
#       7     print("GPU Count:", paddle.device.cuda.device_count())
# ----> 8     print("Current CUDA Device:", paddle.device.cuda.current_device())
#       9     print("GPU Name:", paddle.device.cuda.get_device_name(0))
#
# AttributeError: module 'paddle.device.cuda' has no attribute 'current_device'

# %%
import paddle

print("Paddle version:", paddle.__version__)
print("Device:", paddle.device.get_device())
print("CUDA support:", paddle.is_compiled_with_cuda())
# Out:
# Paddle version: 2.6.2
# Device: gpu:0
# CUDA support: True

# %%
# $env:PYTHONUTF8=1
# python tools/infer_rec.py -c output/rec_ppocr_v4/config.yml -o Global.infer_img=data_OCR/final_data/img_1.jpg
